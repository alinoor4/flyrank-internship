# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alinoor4/flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/alinoor4/flyrank-internship.git
import os

readme_path = 'flyrank-internship/skills/README.md'
if os.path.exists(readme_path):
    with open(readme_path, 'r') as f:
        print(f.read())
else:
    print(f'File still not found at {readme_path}. Please check the path.')
# Out:
# Cloning into 'flyrank-internship'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 129 (delta 43), reused 85 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 1.89 MiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# # Skills — the router
#
# This folder is a small library of **skills**: focused instruction files your AI assistant loads
# one at a time. One skill per task keeps the assistant sharp — its context window is small, and
# filling it with everything makes it worse at the one thing you need.
#
# **How to use it (repo-reading agents — Claude Code, Cursor, Codex):** they find this file
# automatically via `AGENTS.md` / `CLAUDE.md`. Just tell your assistant which task you're doing.
#
# **Using a chat-only assistant (ChatGPT / Gemini in a browser)?** Open the skill file on GitHub,
# ...

# %%
skill_path = 'flyrank-internship/skills/framing-ml-problems/SKILL.md'
with open(skill_path, 'r') as f:
    print(f.read())
# Out:
# ---
# name: framing-ml-problems
# description: Frames a data/ML problem before any modeling — the decision, the action, the cost of a wrong call, task type, target, and success metric. Use when picking a project direction, writing a research question, or mapping a problem onto an ML task type.
# ---
#
# # Framing ML problems
#
# A model is never the goal. A better DECISION is the goal. Frame first, model later.
#
# ## The four questions (answer all four, in writing)
#
# 1. **What decision does this improve?** Not "predict X" — decisions. "Which page should an
#    editor fix first?" is a decision. "Predict decline" is not, yet.
# 2. **Who acts on the output, and what do they do?** Name the person and the action. If nobody
#    would act differently, the work has no customer.
# 3. **What does a wrong answer cost?** Wasted editor hours? A missed decline? The cost of errors
#    decides how careful the method must be, and which errors matter more.
# ...

# %%
data_skill_path = 'flyrank-internship/skills/flyrank/flyrank-data/SKILL.md'
if os.path.exists(data_skill_path):
    with open(data_skill_path, 'r') as f:
        print(f.read())
else:
    print('FlyRank data skill file not found.')
# Out:
# ---
# name: flyrank-data
# description: The FlyRank internship datasets — the 30k-row starter CSV and its gotchas, the ~79M-row warehouse release tables and grains, panel warnings, access, and iteration rules. Load for EVERY task that touches the data. (Project-specific: delete this folder when reusing the skill library elsewhere.)
# ---
#
# # FlyRank internship data
#
# Two datasets. The small one ships in this repo; the big one is hosted and gated.
#
# ## 1. Starter dataset (in this repo)
#
# `data/raw/content_refresh_anonymized.csv` — 30,000 rows × 44 columns, one row per pseudonymized
# content item, 32 clients, trailing-90-day metrics. Full column reference: `docs/data-dictionary.md`
# (keep it open). The gotchas that cause 90% of mistakes:
#
# - **Rate columns are ×100 percentages**: `ctr = 0.76` means 0.76%, not 76%. Applies to ctr,
#   engagement_rate, scroll_rate, ai_traffic_pct, trend_pct.
# - **`avg_position = 0` means "no data"**, not rank zero (1,205 rows).
# ...

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is a **Ranking/Scoring** task. The goal is to prioritize which content items an editor should refresh first. By producing a priority score, we help the editor focus their limited hours on the pages most likely to benefit from an update, measured by potential traffic recovery.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is an **observed outcome**: the `trend_pct` (percentage change in traffic). We are specifically looking for pages where this value is significantly negative. We avoid `is_declining_label` as a target because it is a defined rule, and we want the model to learn the underlying traffic patterns instead.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# The success metric is **Precision@K**. Since an editor only has time to fix a limited number of pages (K) per week, we want to ensure that the top K pages suggested by the model are actually those experiencing genuine, addressable declines.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is a **content item per client**. Each row in the dataframe represents a unique content piece, identified by `content_id` and `client_id`, with its associated performance metrics over a 90-day window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import pandas as pd

# Load the starter dataset to see the grain and available signals
data_path = 'flyrank-internship/data/raw/content_refresh_anonymized.csv'
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print(f"Dataset shape: {df.shape}")
    display(df.head())
    # Check for the grain: one row per content item per client
    grain_check = df.groupby(['client_id', 'content_id']).size().max()
    print(f"Max rows per (client, content) pair: {grain_check} (1 means grain is content item)")
else:
    print(f"Data file not found at {data_path}")
# Out:
# Dataset shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# ML is flexible in the changes made to the data and the procedure, fixed rules only complicate things here.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
